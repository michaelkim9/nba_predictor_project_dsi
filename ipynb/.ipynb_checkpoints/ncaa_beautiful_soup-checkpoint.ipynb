# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
def SoupFromURL(url, suppressOutput=True):

    if not suppressOutput:
        print(url)
    try:
        r = requests.get(url)
    except:
        return None

    return BeautifulSoup(r.text, "html5lib")

# %% [markdown]
# ### Scraping player page for stats
#
# The function below scrapes any given player url page for stats

# %%
def ncaa_stats_dict(url):
    player_page = SoupFromURL(str(url))
    
    #player profile info
    a = player_page.find_all('div', attrs={'class':'nothumb'})[0]
    a_soup = BeautifulSoup(str(a),"html5lib")
    a = player_page.find_all('div', attrs={'class':'nothumb'})[0]
    
    try:
        n = str(a_soup.text.split('\n')[1])
        name = n.replace("\t","")
    except:
        name = None
    
    try:
        p = str(a_soup.text.split('\n')[13])
        position = p.replace("  ","")
    except:
        position = None
    
    try:
        ft = float(str(a_soup.text.split('\n')[17])[2])*12
        inch = float(str(a_soup.text.split('\n')[17])[4])
        height = ft+inch
    except:
        height = None
    
    ### high school
    hs_list = []
    try:
        hs = str(a_soup.text.split('\n')[22])
        high_school = hs.replace("  High School: ","")
        hs_list.append(high_school)
    
        hs_2 = str(a_soup.text.split('\n')[26])
        high_school_2 = hs_2.replace("  High School: ","")
        hs_list.append(high_school_2)
        
        hs_list = [x for x in hs_list if not '  ' in x]
        hs_list.append(None)
    except:
        hs_list.append(None)
    
    while '' in hs_list:
        hs_list.remove('')
        
    ### college
    col_list = []
    try:
        c_4 = str(a_soup.text.split('\n')[18])
        college_4 = c_4.replace("  School: ","")
        college_4 = college_4.replace("  Schools: ","")
        col_list.append(college_4)
    
        c = str(a_soup.text.split('\n')[28])
        college = c.replace("  School: ","")
        college = college.replace("  Schools: ","")
        col_list.append(college)
    
        c_2 = str(a_soup.text.split('\n')[32])
        college_2 = c_2.replace("  School: ","")
        college_2 = college_2.replace("  Schools: ","")
        col_list.append(college_2)
    
        c_3 = str(a_soup.text.split('\n')[24])
        college_3 = c_3.replace("  School: ","")
        college_3 = college_3.replace("  Schools: ","")
        col_list.append(college_3)

        col_list = [x for x in col_list if not '  ' in x]
        col_list.append(None)
    except:
        col_list.append(None)

    while '' in col_list:
        col_list.remove('')
    
    #player stats
    stat_list = []
    try:
        p = player_page.find_all('div', attrs={'class':'stats_pullout'})[0]
        p_soup = BeautifulSoup(str(p),"html5lib")
        stat = p_soup.text.split('\n')[1::4][2:]
    
        #stat_list = []
        for s in stat:
            try:
                if s == str(""):
                    stat_list.append(None)
                else:
                    stat_list.append(float(s))
            except:
                stat_list.append(None)
    except:
        stat_list.extend([None,None,None,None,None,None,None,None,None,None])
    
    #season count
    season_count = player_page.find_all('div', attrs={'class':'overthrow table_container'})[0]
    season_count_soup = BeautifulSoup(str(season_count),"html5lib")
    season_count = season_count_soup.text.split('\n')
    season_count = season_count[33:37]
    season_count = [x for x in season_count if not 'Career' in x]
    season_count = [x for x in season_count if not '  ' in x]
    final_season_count = len(list(filter(None, season_count)))
    
    #creating player dictionary
    player_dict = {
        'player_name':name,
        'position':position,
        'height(inches)':height,
        'high_school':hs_list[0],
        'college':col_list[0],
        'years_in_college':final_season_count,
        'games':stat_list[0],
        'points':stat_list[1],
        'rebounds':stat_list[2],
        'assists':stat_list[3],
        'fg_percent':stat_list[4],
        '3_fg_percent':stat_list[5],
        'free_throw_percent':stat_list[6],
        'effective_fg_percent':stat_list[7],
        'player_efficiency_rating':stat_list[8],
        'win_shares':stat_list[9]
    }
    return player_dict

# %%
ncaa_stats_dict('https://www.sports-reference.com/cbb/players/jordan-aaberg-1.html')
# Out:
# {'3_fg_percent': None,
#  'assists': 0.2,
#  'college': 'North Dakota State',
#  'effective_fg_percent': 61.9,
#  'fg_percent': 61.9,
#  'free_throw_percent': 78.8,
#  'games': 115.0,
#  'height(inches)': 81.0,
#  'high_school': 'Rothsay',
#  'player_efficiency_rating': 17.9,
#  'player_name': 'Jordan Aaberg',
#  'points': 3.5,
#  'position': 'Forward',
#  'rebounds': 2.3,
#  'win_shares': 4.6,
#  'years_in_college': 4}

# %% [markdown]
# ### Get index page urls
#
# I noticed that there is a pattern to the player index page url's on sports-reference. I followed the pattern to get a list of url's.

# %%
import string
index_urls = []
for letter in string.ascii_lowercase:
    letter_page = 'https://www.sports-reference.com/cbb/players/{}-index.html'.format(letter)
    index_urls.append(letter_page)

index_urls
# Out:
# ['https://www.sports-reference.com/cbb/players/a-index.html',
#  'https://www.sports-reference.com/cbb/players/b-index.html',
#  'https://www.sports-reference.com/cbb/players/c-index.html',
#  'https://www.sports-reference.com/cbb/players/d-index.html',
#  'https://www.sports-reference.com/cbb/players/e-index.html',
#  'https://www.sports-reference.com/cbb/players/f-index.html',
#  'https://www.sports-reference.com/cbb/players/g-index.html',
#  'https://www.sports-reference.com/cbb/players/h-index.html',
#  'https://www.sports-reference.com/cbb/players/i-index.html',
#  'https://www.sports-reference.com/cbb/players/j-index.html',
#  'https://www.sports-reference.com/cbb/players/k-index.html',
#  'https://www.sports-reference.com/cbb/players/l-index.html',
#  'https://www.sports-reference.com/cbb/players/m-index.html',
#  'https://www.sports-reference.com/cbb/players/n-index.html',
#  'https://www.sports-reference.com/cbb/players/o-index.html',
#  'https://www.sports-reference.com/cbb/players/p-index.html',
#  'https://www.sports-reference.com/cbb/players/q-index.html',
#  'https://www.sports-reference.com/cbb/players/r-index.html',
#  'https://www.sports-reference.com/cbb/players/s-index.html',
#  'https://www.sports-reference.com/cbb/players/t-index.html',
#  'https://www.sports-reference.com/cbb/players/u-index.html',
#  'https://www.sports-reference.com/cbb/players/v-index.html',
#  'https://www.sports-reference.com/cbb/players/w-index.html',
#  'https://www.sports-reference.com/cbb/players/x-index.html',
#  'https://www.sports-reference.com/cbb/players/y-index.html',
#  'https://www.sports-reference.com/cbb/players/z-index.html']

# %% [markdown]
# ### Get player urls
#
# Within each of the index pages, there was a pattern within the HTML code that references all the links on the page. I scraped all the links and discarded the ones that weren't relevant such as the links to schools or other parts of the site that weren't player pages.

# %%
def get_player_urls(index_url_link):

    player_urls = []
    index_page = SoupFromURL(index_url_link)
    index_names = index_page.find_all('p')
    index_soup = BeautifulSoup(str(index_names),"html5lib")
    links = index_soup('a', href=True)
    
    for l in links:
        try:
            player_urls.append('https://www.sports-reference.com' + l.attrs['href'])
        except:
            pass
    
    player_urls = [x for x in player_urls if not 'schools' in x]
    player_urls.pop()
    player_urls.pop()
    player_urls.pop()
    player_urls.pop()
    return player_urls

# %%
get_player_urls('https://www.sports-reference.com/cbb/players/x-index.html')
# Out:
# ['https://www.sports-reference.com/cbb/players/jeff-xavier-1.html',
#  'https://www.sports-reference.com/cbb/players/ioannis-xenakis-1.html',
#  'https://www.sports-reference.com/cbb/players/aaron-xia-1.html',
#  'https://www.sports-reference.com/cbb/players/ji-xiang-1.html',
#  'https://www.sports-reference.com/cbb/players/oliver-xu-1.html',
#  'https://www.sports-reference.com/cbb/players/tao-xu-1.html']

# %% [markdown]
# ### Generate Stats Dataframe Of All Players On Index Page
#
# Now that I have a function to scrape player pages for their stats and a list of index_urls with a function to get all the page urls, I decided to create another function below where you pass in the index url to generate a dataframe with player stats for all players listed on that page.

# %%
def generate_player_df(index_url_link):
    
    player_urls = []
    index_page = SoupFromURL(index_url_link)
    index_names = index_page.find_all('p')
    index_soup = BeautifulSoup(str(index_names),"html5lib")
    links = index_soup('a', href=True)
    
    for l in links:
        try:
            player_urls.append('https://www.sports-reference.com' + l.attrs['href'])
        except:
            pass
    
    player_urls = [x for x in player_urls if not 'schools' in x]
    player_urls.pop()
    player_urls.pop()
    player_urls.pop()
    player_urls.pop()
    
    player_stats_list=[]
    for url in player_urls:
        player_stats_list.append(ncaa_stats_dict(url))
        print(url)
    
    df = pd.DataFrame(player_stats_list)
    df = df[[
        'player_name',
        'position',
        'height(inches)',
        'high_school',
        'college',
        'years_in_college',
        'games',
        'points',
        'rebounds',
        'assists',
        'fg_percent',
        '3_fg_percent',
        'free_throw_percent',
        'effective_fg_percent',
        'player_efficiency_rating',
        'win_shares'
    ]]
    
    return df

# %%
z_df = generate_player_df('https://www.sports-reference.com/cbb/players/z-index.html')
# Out:
# https://www.sports-reference.com/cbb/players/marvin-zaandam-1.html
# https://www.sports-reference.com/cbb/players/kevin-zabo-1.html
# https://www.sports-reference.com/cbb/players/dan-zachary-1.html
# https://www.sports-reference.com/cbb/players/danny-zachary-1.html
# https://www.sports-reference.com/cbb/players/michael-zachary-1.html
# https://www.sports-reference.com/cbb/players/randy-zachary-1.html
# https://www.sports-reference.com/cbb/players/richard-zacher-1.html
# https://www.sports-reference.com/cbb/players/nick-zachery-1.html
# https://www.sports-reference.com/cbb/players/scott-zack-1.html
# https://www.sports-reference.com/cbb/players/steve-zack-1.html
# https://www.sports-reference.com/cbb/players/bill-zadel-1.html
# https://www.sports-reference.com/cbb/players/manny-zafires-1.html
# https://www.sports-reference.com/cbb/players/manny-zafiros-1.html
# https://www.sports-reference.com/cbb/players/petrolsav-zafirov-1.html
# https://www.sports-reference.com/cbb/players/todd-zafirovski-1.html
# https://www.sports-reference.com/cbb/players/bill-zagar-1.html
# https://www.sports-reference.com/cbb/players/mike-zagardo-1.html
# https://www.sports-reference.com/cbb/players/ron-zager-1.html
# https://www.sports-reference.com/cbb/players/chuck-zagozdon-1.html
# https://www.sports-reference.com/cbb/players/kyle-zaharias-1.html
# https://www.sports-reference.com/cbb/players/nick-zaharias-1.html
# https://www.sports-reference.com/cbb/players/adam-zahn-1.html
# https://www.sports-reference.com/cbb/players/alan-zahn-1.html
# https://www.sports-reference.com/cbb/players/andrew-zahn-1.html
# https://www.sports-reference.com/cbb/players/andrew-zahora-1.html
# https://www.sports-reference.com/cbb/players/bob-zaiac-1.html
# https://www.sports-reference.com/cbb/players/bob-zajac-1.html
# https://www.sports-reference.com/cbb/players/craig-zajac-1.html
# https://www.sports-reference.com/cbb/players/ed-zajac-1.html
# https://www.sports-reference.com/cbb/players/jon-zajac-1.html
# https://www.sports-reference.com/cbb/players/richie-zajac-1.html
# https://www.sports-reference.com/cbb/players/bob-zak-1.html
# https://www.sports-reference.com/cbb/players/dave-zak-1.html
# https://www.sports-reference.com/cbb/players/jim-zak-1.html
# https://www.sports-reference.com/cbb/players/mike-zak-1.html
# https://www.sports-reference.com/cbb/players/ted-zak-1.html
# https://www.sports-reference.com/cbb/players/_-zak-2.html
# https://www.sports-reference.com/cbb/players/_-zak-3.html
# https://www.sports-reference.com/cbb/players/john-zakariassen-1.html
# https://www.sports-reference.com/cbb/players/mike-zaklan-1.html
# https://www.sports-reference.com/cbb/players/casey-zakowski-1.html
# https://www.sports-reference.com/cbb/players/steve-zakula-1.html
# https://www.sports-reference.com/cbb/players/matt-zalauskas-1.html
# https://www.sports-reference.com/cbb/players/jim-zalenka-1.html
# https://www.sports-reference.com/cbb/players/matt-zaleski-1.html
# https://www.sports-reference.com/cbb/players/bob-zaletal-1.html
# https://www.sports-reference.com/cbb/players/bob-zaletel-1.html
# https://www.sports-reference.com/cbb/players/joe-zaletel-1.html
# https://www.sports-reference.com/cbb/players/tom-zaliagiris-1.html
# https://www.sports-reference.com/cbb/players/george-zalucki-1.html
# https://www.sports-reference.com/cbb/players/paulius-zalys-1.html
# https://www.sports-reference.com/cbb/players/mark-zamat-1.html
# https://www.sports-reference.com/cbb/players/_-zamat-2.html
# https://www.sports-reference.com/cbb/players/george-zambetti-1.html
# https://www.sports-reference.com/cbb/players/steve-zambo-1.html
# https://www.sports-reference.com/cbb/players/joe-zamborsky-1.html
# https://www.sports-reference.com/cbb/players/rod-zamor-1.html
# https://www.sports-reference.com/cbb/players/adrian-zamora-1.html
# https://www.sports-reference.com/cbb/players/jojo-zamora-1.html
# https://www.sports-reference.com/cbb/players/robert-zamora-1.html
# https://www.sports-reference.com/cbb/players/paolo-zamorano-1.html
# https://www.sports-reference.com/cbb/players/brian-zamore-1.html
# https://www.sports-reference.com/cbb/players/alex-zampier-1.html
# https://www.sports-reference.com/cbb/players/davide-zanbon-1.html
# https://www.sports-reference.com/cbb/players/allyn-zanchi-1.html
# https://www.sports-reference.com/cbb/players/dan-zanderson-1.html
# https://www.sports-reference.com/cbb/players/len-zandy-1.html
# https://www.sports-reference.com/cbb/players/stewart-zane-1.html
# https://www.sports-reference.com/cbb/players/stewart-zane-2.html
# https://www.sports-reference.com/cbb/players/matt-zaney-1.html
# https://www.sports-reference.com/cbb/players/michael-zangari-1.html
# https://www.sports-reference.com/cbb/players/george-zaninovich-1.html
# https://www.sports-reference.com/cbb/players/george-zaninovich-2.html
# https://www.sports-reference.com/cbb/players/nura-zanna-1.html
# https://www.sports-reference.com/cbb/players/talib-zanna-1.html
# https://www.sports-reference.com/cbb/players/rudy-zannini-1.html
# https://www.sports-reference.com/cbb/players/craig-zanon-1.html
# https://www.sports-reference.com/cbb/players/rick-zanon-1.html
# https://www.sports-reference.com/cbb/players/scott-zanon-1.html
# https://www.sports-reference.com/cbb/players/pete-van-zant-1.html
# https://www.sports-reference.com/cbb/players/john-zanzalari-1.html
# https://www.sports-reference.com/cbb/players/tony-zanze-1.html
# https://www.sports-reference.com/cbb/players/tommy-zapata-1.html
# https://www.sports-reference.com/cbb/players/ron-zappia-1.html
# https://www.sports-reference.com/cbb/players/zack-zaragoza-1.html
# https://www.sports-reference.com/cbb/players/joe-zaranka-1.html
# https://www.sports-reference.com/cbb/players/stan-zardozny-1.html
# https://www.sports-reference.com/cbb/players/andrew-zarechnak-1.html
# https://www.sports-reference.com/cbb/players/nemanja-zarkovic-1.html
# https://www.sports-reference.com/cbb/players/bob-zarr-1.html
# https://www.sports-reference.com/cbb/players/max-zaslofsky-1.html
# https://www.sports-reference.com/cbb/players/eric-zastoupil-1.html
# https://www.sports-reference.com/cbb/players/ed-zastrow-1.html
# https://www.sports-reference.com/cbb/players/nate-zastrow-1.html
# https://www.sports-reference.com/cbb/players/butch-zatezalo-1.html
# https://www.sports-reference.com/cbb/players/rudy-zatezalo-1.html
# https://www.sports-reference.com/cbb/players/jeff-zatkoff-1.html
# https://www.sports-reference.com/cbb/players/john-zatorski-1.html
# https://www.sports-reference.com/cbb/players/ed-zausch-1.html
# https://www.sports-reference.com/cbb/players/ed-zausch-2.html
# https://www.sports-reference.com/cbb/players/donatas-zavackas-1.html
# https://www.sports-reference.com/cbb/players/jeff-zavada-1.html
# https://www.sports-reference.com/cbb/players/jeff-zavada-2.html
# https://www.sports-reference.com/cbb/players/javier-zavala-1.html
# https://www.sports-reference.com/cbb/players/bob-zavorskas-1.html
# https://www.sports-reference.com/cbb/players/tom-zavorskas-1.html
# https://www.sports-reference.com/cbb/players/ron-zawacki-1.html
# https://www.sports-reference.com/cbb/players/ted-zawacki-1.html
# https://www.sports-reference.com/cbb/players/ray-zawackzki-1.html
# https://www.sports-reference.com/cbb/players/ray-zawadski-1.html
# https://www.sports-reference.com/cbb/players/ray-zawadzki-1.html
# https://www.sports-reference.com/cbb/players/joe-zawawacki-1.html
# https://www.sports-reference.com/cbb/players/bob-zawoluk-1.html
# https://www.sports-reference.com/cbb/players/steve-zazuri-1.html
# https://www.sports-reference.com/cbb/players/frank-zazzaro-1.html
# https://www.sports-reference.com/cbb/players/john-zazzaro-1.html
# https://www.sports-reference.com/cbb/players/bill-zban-1.html
# https://www.sports-reference.com/cbb/players/larry-zebrack-1.html
# https://www.sports-reference.com/cbb/players/stefan-zecevic-1.html
# https://www.sports-reference.com/cbb/players/gene-zech-1.html
# https://www.sports-reference.com/cbb/players/patrick-zeck-1.html
# https://www.sports-reference.com/cbb/players/tyler-zegarzewski-1.html
# https://www.sports-reference.com/cbb/players/joe-zeglinski-1.html
# https://www.sports-reference.com/cbb/players/sammy-zeglinski-1.html
# https://www.sports-reference.com/cbb/players/zack-zeglinski-1.html
# https://www.sports-reference.com/cbb/players/andrew-zehnder-1.html
# https://www.sports-reference.com/cbb/players/todd-zehner-1.html
# https://www.sports-reference.com/cbb/players/john-zeides-1.html
# https://www.sports-reference.com/cbb/players/_-zeiff-1.html
# https://www.sports-reference.com/cbb/players/_-zeiff-2.html
# https://www.sports-reference.com/cbb/players/dick-zeiger-1.html
# https://www.sports-reference.com/cbb/players/bo-zeigler-1.html
# https://www.sports-reference.com/cbb/players/dave-zeigler-1.html
# https://www.sports-reference.com/cbb/players/demitrius-zeigler-1.html
# https://www.sports-reference.com/cbb/players/derrick-zeigler-1.html
# https://www.sports-reference.com/cbb/players/ernie-zeigler-2.html
# https://www.sports-reference.com/cbb/players/kenny-zeigler-1.html
# https://www.sports-reference.com/cbb/players/marcus-zeigler-1.html
# https://www.sports-reference.com/cbb/players/mitchell-zeigler-1.html
# https://www.sports-reference.com/cbb/players/omar-zeigler-1.html
# https://www.sports-reference.com/cbb/players/trey-zeigler-1.html
# https://www.sports-reference.com/cbb/players/nick-zeisloft-1.html
# https://www.sports-reference.com/cbb/players/dick-zeitler-1.html
# https://www.sports-reference.com/cbb/players/bill-zeits-1.html
# https://www.sports-reference.com/cbb/players/branimir-zeko-1.html
# https://www.sports-reference.com/cbb/players/ray-zelek-1.html
# https://www.sports-reference.com/cbb/players/andrej-zelenbaba-1.html
# https://www.sports-reference.com/cbb/players/frank-zelesnik-1.html
# https://www.sports-reference.com/cbb/players/dick-zelickson-1.html
# https://www.sports-reference.com/cbb/players/andrew-zelis-1.html
# https://www.sports-reference.com/cbb/players/cody-zeller-1.html
# https://www.sports-reference.com/cbb/players/dave-zeller-1.html
# https://www.sports-reference.com/cbb/players/gary-zeller-1.html
# https://www.sports-reference.com/cbb/players/luke-zeller-1.html
# https://www.sports-reference.com/cbb/players/marty-zeller-1.html
# https://www.sports-reference.com/cbb/players/tyler-zeller-1.html
# https://www.sports-reference.com/cbb/players/ed-zello-1.html
# https://www.sports-reference.com/cbb/players/damian-zellous-1.html
# https://www.sports-reference.com/cbb/players/steve-zemba-1.html
# https://www.sports-reference.com/cbb/players/dick-zembal-1.html
# https://www.sports-reference.com/cbb/players/john-zembron-1.html
# https://www.sports-reference.com/cbb/players/deividas-zemgulis-1.html
# https://www.sports-reference.com/cbb/players/bob-zender-1.html
# https://www.sports-reference.com/cbb/players/martin-zeno-1.html
# https://www.sports-reference.com/cbb/players/michael-zeno-1.html
# https://www.sports-reference.com/cbb/players/michael-zeno-2.html
# https://www.sports-reference.com/cbb/players/michael-zeno-3.html
# https://www.sports-reference.com/cbb/players/tony-zeno-1.html
# https://www.sports-reference.com/cbb/players/guy-zenou-1.html
# https://www.sports-reference.com/cbb/players/mike-zepeda-1.html
# https://www.sports-reference.com/cbb/players/keil-zepernick-1.html
# https://www.sports-reference.com/cbb/players/timothy-zephyr-1.html
# https://www.sports-reference.com/cbb/players/neven-zeravica-1.html
# https://www.sports-reference.com/cbb/players/chris-zerbe-1.html
# https://www.sports-reference.com/cbb/players/paul-zeringue-1.html
# https://www.sports-reference.com/cbb/players/jeff-zern-1.html
# https://www.sports-reference.com/cbb/players/michael-zernich-1.html
# https://www.sports-reference.com/cbb/players/_-zerwas-1.html
# https://www.sports-reference.com/cbb/players/peter-zestermann-1.html
# https://www.sports-reference.com/cbb/players/_-zetz-2.html
# https://www.sports-reference.com/cbb/players/al-zetzsche-1.html
# https://www.sports-reference.com/cbb/players/phil-zevenbergen-1.html
# https://www.sports-reference.com/cbb/players/max-zhang-1.html
# https://www.sports-reference.com/cbb/players/alex-zhao-1.html
# https://www.sports-reference.com/cbb/players/andrew-zidar-1.html
# https://www.sports-reference.com/cbb/players/george-zidek-1.html
# https://www.sports-reference.com/cbb/players/malte-ziegenhagen-1.html
# https://www.sports-reference.com/cbb/players/jerry-ziegenhorn-1.html
# https://www.sports-reference.com/cbb/players/_-ziegenhorn-1.html
# https://www.sports-reference.com/cbb/players/bob-ziegler-1.html
# https://www.sports-reference.com/cbb/players/don-ziegler-1.html
# https://www.sports-reference.com/cbb/players/fritz-ziegler-1.html
# https://www.sports-reference.com/cbb/players/karl-ziegler-1.html
# https://www.sports-reference.com/cbb/players/lonnie-ziegler-1.html
# https://www.sports-reference.com/cbb/players/m-ziegler-1.html
# https://www.sports-reference.com/cbb/players/rick-ziegler-1.html
# https://www.sports-reference.com/cbb/players/ron-ziegler-1.html
# https://www.sports-reference.com/cbb/players/todd-ziegler-1.html
# https://www.sports-reference.com/cbb/players/todd-ziegler-2.html
# https://www.sports-reference.com/cbb/players/travis-ziegler-1.html
# https://www.sports-reference.com/cbb/players/travis-ziegler-2.html
# https://www.sports-reference.com/cbb/players/matt-zielenbach-1.html
# https://www.sports-reference.com/cbb/players/frank-zielinski-1.html
# https://www.sports-reference.com/cbb/players/jerry-zielinski-1.html
# https://www.sports-reference.com/cbb/players/maciej-zielinski-1.html
# https://www.sports-reference.com/cbb/players/russ-ziemba-1.html
# https://www.sports-reference.com/cbb/players/steve-ziemian-1.html
# https://www.sports-reference.com/cbb/players/chris-zier-1.html
# https://www.sports-reference.com/cbb/players/isaiah-zierden-1.html
# https://www.sports-reference.com/cbb/players/larry-zigerelli-1.html
# https://www.sports-reference.com/cbb/players/matt-zignorski-1.html
# https://www.sports-reference.com/cbb/players/tim-ziko-1.html
# https://www.sports-reference.com/cbb/players/chris-zikos-1.html
# https://www.sports-reference.com/cbb/players/_-zikos-2.html
# https://www.sports-reference.com/cbb/players/steve-zilko-1.html
# https://www.sports-reference.com/cbb/players/giacomo-zilli-1.html
# https://www.sports-reference.com/cbb/players/greg-zilverberg-1.html
# https://www.sports-reference.com/cbb/players/stanley-zima-1.html
# https://www.sports-reference.com/cbb/players/stanley-zima-2.html
# https://www.sports-reference.com/cbb/players/andrew-zimbro-1.html
# https://www.sports-reference.com/cbb/players/ken-zimko-1.html
# https://www.sports-reference.com/cbb/players/bill-zimmer-1.html
# https://www.sports-reference.com/cbb/players/jason-zimmer-1.html
# https://www.sports-reference.com/cbb/players/adam-zimmerman-1.html
# https://www.sports-reference.com/cbb/players/ben-zimmerman-1.html
# https://www.sports-reference.com/cbb/players/chris-zimmerman-1.html
# https://www.sports-reference.com/cbb/players/d-zimmerman-3.html
# https://www.sports-reference.com/cbb/players/dave-zimmerman-1.html
# https://www.sports-reference.com/cbb/players/derrick-zimmerman-1.html
# https://www.sports-reference.com/cbb/players/don-zimmerman-1.html
# https://www.sports-reference.com/cbb/players/fred-zimmerman-1.html
# https://www.sports-reference.com/cbb/players/gerald-zimmerman-1.html
# https://www.sports-reference.com/cbb/players/j-zimmerman-1.html
# https://www.sports-reference.com/cbb/players/jack-zimmerman-1.html
# https://www.sports-reference.com/cbb/players/jack-zimmerman-2.html
# https://www.sports-reference.com/cbb/players/james-zimmerman-1.html
# https://www.sports-reference.com/cbb/players/jason-zimmerman-1.html
# https://www.sports-reference.com/cbb/players/jim-zimmerman-1.html
# https://www.sports-reference.com/cbb/players/joe-zimmerman-1.html
# https://www.sports-reference.com/cbb/players/pete-zimmerman-1.html
# https://www.sports-reference.com/cbb/players/rodney-zimmerman-1.html
# https://www.sports-reference.com/cbb/players/scott-zimmerman-1.html
# https://www.sports-reference.com/cbb/players/thurman-zimmerman-1.html
# https://www.sports-reference.com/cbb/players/todd-zimmerman-2.html
# https://www.sports-reference.com/cbb/players/todd-zimmerman-1.html
# https://www.sports-reference.com/cbb/players/stephen-zimmermanjr-1.html
# https://www.sports-reference.com/cbb/players/andrew-zimmermann-1.html
# https://www.sports-reference.com/cbb/players/frank-zimmovan-1.html
# https://www.sports-reference.com/cbb/players/alex-zimnickas-1.html
# https://www.sports-reference.com/cbb/players/greg-zimny-1.html
# https://www.sports-reference.com/cbb/players/scott-zimos-1.html
# https://www.sports-reference.com/cbb/players/ted-zimowicz-1.html
# https://www.sports-reference.com/cbb/players/david-zingg-1.html
# https://www.sports-reference.com/cbb/players/john-zinirich-1.html
# https://www.sports-reference.com/cbb/players/dave-zink-1.html
# https://www.sports-reference.com/cbb/players/gary-zinkgraf-1.html
# https://www.sports-reference.com/cbb/players/chuck-zinky-1.html
# https://www.sports-reference.com/cbb/players/jim-zinn-1.html
# https://www.sports-reference.com/cbb/players/rob-zinn-1.html
# https://www.sports-reference.com/cbb/players/terry-zinn-1.html
# https://www.sports-reference.com/cbb/players/walt-zinn-1.html
# https://www.sports-reference.com/cbb/players/paul-zinser-1.html
# https://www.sports-reference.com/cbb/players/bill-zinsky-1.html
# https://www.sports-reference.com/cbb/players/jim-zinsky-1.html
# https://www.sports-reference.com/cbb/players/mark-ziolko-1.html
# https://www.sports-reference.com/cbb/players/john-zipp-1.html
# https://www.sports-reference.com/cbb/players/_-zippel-1.html
# https://www.sports-reference.com/cbb/players/jon-ziri-1.html
# https://www.sports-reference.com/cbb/players/alexander-ziskunov-1.html
# https://www.sports-reference.com/cbb/players/matt-zitani-1.html
# https://www.sports-reference.com/cbb/players/fred-zitar-1.html
# https://www.sports-reference.com/cbb/players/_-zitar-2.html
# https://www.sports-reference.com/cbb/players/lou-ziter-1.html
# https://www.sports-reference.com/cbb/players/bill-zito-1.html
# https://www.sports-reference.com/cbb/players/john-zito-1.html
# https://www.sports-reference.com/cbb/players/ales-zivanovic-1.html
# https://www.sports-reference.com/cbb/players/milos-zivanovic-1.html
# https://www.sports-reference.com/cbb/players/mitar-zivanovic-1.html
# https://www.sports-reference.com/cbb/players/luka-zivkovic-1.html
# https://www.sports-reference.com/cbb/players/chris-zivney-1.html
# https://www.sports-reference.com/cbb/players/lubo-zizakovic-1.html
# https://www.sports-reference.com/cbb/players/jay-ziznewski-1.html
# https://www.sports-reference.com/cbb/players/steve-zlko-1.html
# https://www.sports-reference.com/cbb/players/drazen-zlovaric-1.html
# https://www.sports-reference.com/cbb/players/aaron-zobrist-1.html
# https://www.sports-reference.com/cbb/players/john-zoccali-1.html
# https://www.sports-reference.com/cbb/players/alex-zock-1.html
# https://www.sports-reference.com/cbb/players/roger-zoeller-1.html
# https://www.sports-reference.com/cbb/players/kirsten-zoellner-1.html
# https://www.sports-reference.com/cbb/players/jim-zoet-1.html
# https://www.sports-reference.com/cbb/players/mark-zoller-1.html
# https://www.sports-reference.com/cbb/players/klaas-zollner-1.html
# https://www.sports-reference.com/cbb/players/vinny-zollo-1.html
# https://www.sports-reference.com/cbb/players/charles-zolot-1.html
# https://www.sports-reference.com/cbb/players/chas-zolot-1.html
# https://www.sports-reference.com/cbb/players/chick-zomlefer-1.html
# https://www.sports-reference.com/cbb/players/mike-zona-1.html
# https://www.sports-reference.com/cbb/players/kenrick-zondervan-1.html
# https://www.sports-reference.com/cbb/players/sean-zone-1.html
# https://www.sports-reference.com/cbb/players/bill-zopf-1.html
# https://www.sports-reference.com/cbb/players/paul-zorad-1.html
# https://www.sports-reference.com/cbb/players/bob-zoretich-1.html
# https://www.sports-reference.com/cbb/players/danijel-zoric-1.html
# https://www.sports-reference.com/cbb/players/bill-zorn-1.html
# https://www.sports-reference.com/cbb/players/tyler-zornes-1.html
# https://www.sports-reference.com/cbb/players/dave-zornow-1.html
# https://www.sports-reference.com/cbb/players/paul-zorsky-1.html
# https://www.sports-reference.com/cbb/players/ezra-zoschke-1.html
# https://www.sports-reference.com/cbb/players/brian-zoubek-1.html
# https://www.sports-reference.com/cbb/players/nisre-zouzoua-1.html
# https://www.sports-reference.com/cbb/players/adrian-zuber-1.html
# https://www.sports-reference.com/cbb/players/_-zuber-2.html
# https://www.sports-reference.com/cbb/players/aitor-zubizarreta-1.html
# https://www.sports-reference.com/cbb/players/mark-zubor-1.html
# https://www.sports-reference.com/cbb/players/_-zucco-1.html
# https://www.sports-reference.com/cbb/players/henry-zuchowski-1.html
# https://www.sports-reference.com/cbb/players/ed-zucker-1.html
# https://www.sports-reference.com/cbb/players/maros-zuffa-1.html
# https://www.sports-reference.com/cbb/players/cale-zuiker-1.html
# https://www.sports-reference.com/cbb/players/jake-zuilhof-1.html
# https://www.sports-reference.com/cbb/players/vladimir-zujovic-1.html
# https://www.sports-reference.com/cbb/players/jay-zulauf-1.html
# https://www.sports-reference.com/cbb/players/jay-zulauf-2.html
# https://www.sports-reference.com/cbb/players/jon-zulauf-1.html
# https://www.sports-reference.com/cbb/players/jon-zulauf-2.html
# https://www.sports-reference.com/cbb/players/gordie-zullges-1.html
# https://www.sports-reference.com/cbb/players/jimmy-zullo-1.html
# https://www.sports-reference.com/cbb/players/arthur-zulu-1.html
# https://www.sports-reference.com/cbb/players/george-zumbro-1.html
# https://www.sports-reference.com/cbb/players/chip-zumer-1.html
# https://www.sports-reference.com/cbb/players/neal-zumwalt-1.html
# https://www.sports-reference.com/cbb/players/carlos-zuniga-1.html
# https://www.sports-reference.com/cbb/players/_-zuniga-1.html
# https://www.sports-reference.com/cbb/players/dave-zupan-1.html
# https://www.sports-reference.com/cbb/players/zeljko-zupic-1.html
# https://www.sports-reference.com/cbb/players/johnny-zuppardo-1.html
# https://www.sports-reference.com/cbb/players/joe-zuravleff-1.html
# https://www.sports-reference.com/cbb/players/phil-zuravleff-1.html
# https://www.sports-reference.com/cbb/players/chris-zurcher-1.html
# https://www.sports-reference.com/cbb/players/kim-zurcher-1.html
# https://www.sports-reference.com/cbb/players/drew-zurek-1.html
# https://www.sports-reference.com/cbb/players/george-zurenda-1.html
# https://www.sports-reference.com/cbb/players/stephen-zurich-1.html
# https://www.sports-reference.com/cbb/players/darren-zusack-1.html
# https://www.sports-reference.com/cbb/players/xabi-zusperreguy-1.html
# https://www.sports-reference.com/cbb/players/stanislav-zuzak-1.html
# https://www.sports-reference.com/cbb/players/al-zvinakis-1.html
# https://www.sports-reference.com/cbb/players/al-zvinakos-1.html
# https://www.sports-reference.com/cbb/players/al-zvoda-1.html
# https://www.sports-reference.com/cbb/players/brian-zvonceck-1.html
# https://www.sports-reference.com/cbb/players/brian-zvonecek-1.html
# https://www.sports-reference.com/cbb/players/john-zwakman-1.html
# https://www.sports-reference.com/cbb/players/mark-zwart-1.html
# https://www.sports-reference.com/cbb/players/clint-zwayer-1.html
# https://www.sports-reference.com/cbb/players/eric-zwayer-1.html
# https://www.sports-reference.com/cbb/players/walter-zwick-1.html
# https://www.sports-reference.com/cbb/players/serge-zwikker-1.html
# https://www.sports-reference.com/cbb/players/joe-zych-1.html
# https://www.sports-reference.com/cbb/players/lou-zykiewicz-1.html
# https://www.sports-reference.com/cbb/players/jack-zyla-1.html
# https://www.sports-reference.com/cbb/players/michal-zylinski-1.html
# https://www.sports-reference.com/cbb/players/brock-zylstra-1.html
# https://www.sports-reference.com/cbb/players/gene-zysda-1.html
# https://www.sports-reference.com/cbb/players/gene-zyzda-1.html

# %%
z_df.head()

# %% [markdown]
# Code below to troubleshoot college column

# %%
player_page = SoupFromURL('https://www.sports-reference.com/cbb/players/jordan-aaberg-1.html')
    
a = player_page.find_all('div', attrs={'class':'nothumb'})[0]
a_soup = BeautifulSoup(str(a),"html5lib")


col_list = []
try:
    c_4 = str(a_soup.text.split('\n')[18])
    college_4 = c_4.replace("  School: ","")
    college_4 = college_4.replace("  Schools: ","")
    col_list.append(college_4)
    
    c = str(a_soup.text.split('\n')[28])
    college = c.replace("  School: ","")
    college = college.replace("  Schools: ","")
    col_list.append(college)
    
    c_2 = str(a_soup.text.split('\n')[32])
    college_2 = c_2.replace("  School: ","")
    college_2 = college_2.replace("  Schools: ","")
    col_list.append(college_2)
    
    c_3 = str(a_soup.text.split('\n')[24])
    college_3 = c_3.replace("  School: ","")
    college_3 = college_3.replace("  Schools: ","")
    col_list.append(college_3)

        #final_college = list(filter(None, col_list))
        #final_college.append(None)
    col_list = [x for x in col_list if not '  ' in x]
    col_list.append(None)
except:
    col_list.append(None)

while '' in col_list:
    col_list.remove('')
    
col_list

# %%
player_page = SoupFromURL('https://www.sports-reference.com/cbb/players/_-ziegenhorn-1.html')

col_list_2 = []
a = player_page.find_all('div', attrs={'class':'nothumb'})[0]
a_soup = BeautifulSoup(str(a),"html5lib")

col_5 = str(a_soup.text.split('\n')[18])

col_list_2.append(col_5)

col_list_2
